# %% [markdown]
# <a href="https://colab.research.google.com/github/sintojoy/thinkpalm-agentai-SintoJoy-ReAct_Agent/blob/main/Lab2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0" />
  <title>AI Quiz Challenge</title>

  <style>
    * {
      margin: 0;
      padding: 0;
      box-sizing: border-box;
      font-family: 'Segoe UI', sans-serif;
    }

    body {
      background: linear-gradient(135deg, #f5f7ff, #eef2ff);
      padding: 30px;
      color: #111827;
    }

    .container {
      max-width: 1450px;
      margin: auto;
    }

    /* HEADER */
    .header {
      background: rgba(255,255,255,0.9);
      border-radius: 24px;
      padding: 25px 35px;
      display: flex;
      justify-content: space-between;
      align-items: center;
      box-shadow: 0 8px 25px rgba(0,0,0,0.06);
      margin-bottom: 25px;
    }

    .logo-section {
      display: flex;
      align-items: center;
      gap: 18px;
    }

    .logo {
      width: 65px;
      height: 65px;
      border-radius: 18px;
      background: linear-gradient(135deg, #7c3aed, #4f46e5);
      display: flex;
      align-items: center;
      justify-content: center;
      color: white;
      font-size: 32px;
    }

    .title {
      font-size: 38px;
      font-weight: 700;
    }

    .subtitle {
      color: #64748b;
      margin-top: 5px;
      font-size: 18px;
    }

    .score-card {
      background: white;
      border-radius: 22px;
      padding: 20px 35px;
      text-align: center;
      box-shadow: 0 6px 15px rgba(0,0,0,0.05);
    }

    .score-card h3 {
      color: #64748b;
      font-size: 18px;
      margin-bottom: 8px;
    }

    .score-card h1 {
      color: #6d28d9;
      font-size: 42px;
    }

    /* LAYOUT */
    .main-layout {
      display: grid;
      grid-template-columns: 2fr 1fr;
      gap: 25px;
    }

    /* LEFT PANEL */
    .quiz-panel {
      background: white;
      border-radius: 28px;
      padding: 35px;
      box-shadow: 0 8px 25px rgba(0,0,0,0.05);
    }

    .progress-top {
      display: flex;
      justify-content: space-between;
      margin-bottom: 10px;
      color: #6d28d9;
      font-weight: 600;
    }

    .progress-bar {
      width: 100%;
      height: 12px;
      background: #e5e7eb;
      border-radius: 12px;
      overflow: hidden;
      margin-bottom: 30px;
    }

    .progress-fill {
      width: 100%;
      height: 100%;
      background: linear-gradient(90deg, #7c3aed, #4f46e5);
    }

    .top-tags {
      display: flex;
      justify-content: space-between;
      margin-bottom: 30px;
    }

    .tag {
      padding: 10px 20px;
      border-radius: 999px;
      background: #ede9fe;
      color: #6d28d9;
      font-weight: 600;
    }

    .question {
      font-size: 46px;
      font-weight: 700;
      line-height: 1.2;
      margin-bottom: 18px;
    }

    .question-sub {
      font-size: 22px;
      color: #64748b;
      margin-bottom: 30px;
    }

    .option {
      width: 100%;
      padding: 24px;
      margin-bottom: 18px;
      border-radius: 20px;
      border: 2px solid #e5e7eb;
      background: white;
      font-size: 22px;
      cursor: pointer;
      transition: 0.3s;
      display: flex;
      align-items: center;
      gap: 15px;
    }

    .option:hover {
      border-color: #7c3aed;
      background: #f5f3ff;
      transform: translateY(-2px);
    }

    .option.selected {
      background: #f5f3ff;
      border-color: #8b5cf6;
      color: #6d28d9;
      font-weight: 600;
    }

    .radio {
      width: 24px;
      height: 24px;
      border-radius: 50%;
      border: 3px solid #cbd5e1;
    }

    .selected .radio {
      border-color: #7c3aed;
      background: #7c3aed;
      box-shadow: inset 0 0 0 5px white;
    }

    .buttons {
      display: flex;
      justify-content: space-between;
      margin-top: 25px;
    }

    .btn {
      padding: 16px 28px;
      border-radius: 18px;
      border: none;
      font-size: 18px;
      font-weight: 600;
      cursor: pointer;
      transition: 0.3s;
    }

    .btn-outline {
      background: white;
      border: 2px solid #ddd;
    }

    .btn-primary {
      background: linear-gradient(135deg, #7c3aed, #4f46e5);
      color: white;
      box-shadow: 0 10px 20px rgba(124,58,237,0.25);
    }

    .btn:hover {
      transform: translateY(-2px);
    }

    /* SIDEBAR */
    .sidebar {
      background: white;
      border-radius: 28px;
      padding: 30px;
      box-shadow: 0 8px 25px rgba(0,0,0,0.05);
    }

    .trophy {
      font-size: 90px;
      text-align: center;
    }

    .sidebar-title {
      font-size: 40px;
      font-weight: 700;
      text-align: center;
      margin-top: 10px;
    }

    .sidebar-sub {
      text-align: center;
      color: #64748b;
      margin-top: 12px;
      font-size: 20px;
      line-height: 1.5;
    }

    .result-card {
      margin-top: 25px;
      background: #faf5ff;
      border-radius: 24px;
      padding: 25px;
      text-align: center;
      border: 1px solid #e9d5ff;
    }

    .result-card h1 {
      color: #6d28d9;
      font-size: 60px;
      margin: 10px 0;
    }

    .accuracy {
      color: #16a34a;
      font-size: 24px;
      font-weight: 600;
    }

    .stats {
      display: grid;
      grid-template-columns: repeat(3,1fr);
      gap: 12px;
      margin-top: 25px;
    }

    .stat-box {
      background: #f8fafc;
      border-radius: 18px;
      padding: 18px;
      text-align: center;
      border: 1px solid #eee;
    }

    .stat-box h2 {
      font-size: 34px;
      margin: 10px 0;
    }

    .insight {
      margin-top: 25px;
      background: #faf5ff;
      border-radius: 20px;
      padding: 22px;
      border: 1px solid #e9d5ff;
    }

    .insight h3 {
      color: #6d28d9;
      margin-bottom: 12px;
    }

    .insight p {
      color: #475569;
      line-height: 1.6;
    }

    .sidebar-buttons {
      display: flex;
      gap: 12px;
      margin-top: 25px;
    }

    /* FOOTER */
    .footer {
      margin-top: 25px;
      background: white;
      border-radius: 24px;
      padding: 22px 30px;
      display: flex;
      justify-content: space-between;
      align-items: center;
      box-shadow: 0 8px 25px rgba(0,0,0,0.05);
    }

    .footer-title {
      color: #6d28d9;
      font-size: 24px;
      font-weight: 700;
    }

    .footer-sub {
      color: #64748b;
      margin-top: 6px;
    }

    @media(max-width:1000px){
      .main-layout{
        grid-template-columns:1fr;
      }

      .question{
        font-size:34px;
      }
    }
  </style>
</head>

<body>

<div class="container">

  <!-- HEADER -->
  <div class="header">

    <div class="logo-section">
      <div class="logo">🧠</div>

      <div>
        <div class="title">AI Quiz Challenge</div>
        <div class="subtitle">Test your knowledge</div>
      </div>
    </div>

    <div class="score-card">
      <h3>Score</h3>
      <h1>3 / 5</h1>
    </div>

  </div>

  <!-- MAIN -->
  <div class="main-layout">

    <!-- LEFT PANEL -->
    <div class="quiz-panel">

      <div class="progress-top">
        <span>Question 5 of 5</span>
        <span>100%</span>
      </div>

      <div class="progress-bar">
        <div class="progress-fill"></div>
      </div>

      <div class="top-tags">
        <div class="tag">🌍 Geography</div>
        <div class="tag">⏱ 00:25</div>
      </div>

      <div class="question">
        What is the largest ocean on Earth?
      </div>

      <div class="question-sub">
        Choose the correct answer from the options below.
      </div>

      <div class="option">
        <div class="radio"></div>
        Atlantic Ocean
      </div>

      <div class="option selected">
        <div class="radio"></div>
        Indian Ocean
      </div>

      <div class="option">
        <div class="radio"></div>
        Arctic Ocean
      </div>

      <div class="option">
        <div class="radio"></div>
        Pacific Ocean
      </div>

      <div class="buttons">
        <button class="btn btn-outline">← Previous</button>
        <button class="btn btn-primary">⚑ Finish Quiz</button>
      </div>

    </div>

    <!-- RIGHT SIDEBAR -->
    <div class="sidebar">

      <div class="trophy">🏆</div>

      <div class="sidebar-title">
        Quiz Completed! 🎉
      </div>

      <div class="sidebar-sub">
        Great effort! Keep learning and challenge yourself more.
      </div>

      <div class="result-card">
        <div>Your Score</div>
        <h1>3 / 5</h1>
        <div class="accuracy">Accuracy: 60%</div>
      </div>

      <div class="stats">

        <div class="stat-box">
          <div>✅</div>
          <h2>3</h2>
          <p>Correct</p>
        </div>

        <div class="stat-box">
          <div>❌</div>
          <h2>2</h2>
          <p>Incorrect</p>
        </div>

        <div class="stat-box">
          <div>📋</div>
          <h2>5</h2>
          <p>Total</p>
        </div>

      </div>

      <div class="insight">
        <h3>🤖 AI Insight</h3>
        <p>
          Keep practicing! You're on the right track.
          Review the explanations and try again to improve your score.
        </p>
      </div>

      <div class="sidebar-buttons">
        <button class="btn btn-outline">📄 Review Answers</button>
        <button class="btn btn-primary">↻ Try Again</button>
      </div>

    </div>

  </div>

  <!-- FOOTER -->
  <div class="footer">

    <div>
      <div class="footer-title">🤖 Powered by AI</div>
      <div class="footer-sub">
        Smart quizzes, instant feedback, and AI insights to help you learn better.


</div>

    <button class="btn btn-outline">💡 How it works</button>

  </div>

</div>

<script>

  // Option Selection
  const options = document.querySelectorAll('.option');

  options.forEach(option => {
    option.addEventListener('click', () => {
      options.forEach(o => o.classList.remove('selected'));
      option.classList.add('selected');
    });
  });

</script>

</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#   <title>AI Quiz Challenge</title>
#
#   <style>
#     * {
#       margin: 0;
#       padding: 0;
#       box-sizing: border-box;
#       font-family: 'Segoe UI', sans-serif;
#     }
#
#     body {
#       background: linear-gradient(135deg, #f5f7ff, #eef2ff);
#       padding: 30px;
#       color: #111827;
#     }
#
#     .container {
#       max-width: 1450px;
#       margin: auto;
#     }
#
#     /* HEADER */
#     .header {
#       background: rgba(255,255,255,0.9);
#       border-radius: 24px;
#       padding: 25px 35px;
#       display: flex;
#       justify-content: space-between;
#       align-items: center;
#       box-shadow: 0 8px 25px rgba(0,0,0,0.06);
#       margin-bottom: 25px;
#     }
#
#     .logo-section {
#       display: flex;
#       align-items: center;
#       gap: 18px;
#     }
#
#     .logo {
# ...

# %%
# Define the quiz data with all 5 questions and their correct answers
quiz_data = [
    {
        'question': 'What is the capital of France?',
        'options': ['London', 'Paris', 'Rome', 'Berlin'],
        'answer': 'Paris'
    },
    {
        'question': 'Which planet is known as the Red Planet?',
        'options': ['Earth', 'Mars', 'Jupiter', 'Venus'],
        'answer': 'Mars'
    },
    {
        'question': 'Who painted the Mona Lisa?',
        'options': ['Vincent van Gogh', 'Pablo Picasso', 'Leonardo da Vinci', 'Claude Monet'],
        'answer': 'Leonardo da Vinci'
    },
    {
        'question': 'What is the chemical symbol for water?',
        'options': ['O2', 'H2O', 'CO2', 'NaCl'],
        'answer': 'H2O'
    },
    {
        'question': 'What is the largest ocean on Earth?',
        'options': ['Atlantic Ocean', 'Indian Ocean', 'Arctic Ocean', 'Pacific Ocean'],
        'answer': 'Pacific Ocean'
    }
]

# %% [markdown]
# Now, let's create a dynamic HTML structure with embedded JavaScript to power the interactive quiz. This code will load questions, handle user answers, and display the final score.

# %%
from IPython.display import HTML
import json

# Embed the quiz_data into the JavaScript as a JSON string
quiz_data_json = json.dumps(quiz_data)

html_content_dynamic = f"""
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0" />
  <title>AI Quiz Challenge</title>
  <style>
    body {{ font-family: 'Segoe UI', sans-serif; background: linear-gradient(135deg, #f5f7ff, #eef2ff); padding: 15px; color: #111827; }}
    .container {{ max-width: 1200px; margin: auto; }}
    .header {{ background: rgba(255,255,255,0.9); border-radius: 18px; padding: 15px 20px; display: flex; justify-content: space-between; align-items: center; box-shadow: 0 4px 15px rgba(0,0,0,0.04); margin-bottom: 15px; }}
    .logo-section {{ display: flex; align-items: center; gap: 12px; }}
    .logo {{ width: 50px; height: 50px; border-radius: 12px; background: linear-gradient(135deg, #7c3aed, #4f46e5); display: flex; align-items: center; justify-content: center; color: white; font-size: 24px; }}
    .title {{ font-size: 28px; font-weight: 700; }}
    .subtitle {{ color: #64748b; margin-top: 3px; font-size: 14px; }}
    .score-card {{ background: white; border-radius: 16px; padding: 10px 20px; text-align: center; box-shadow: 0 3px 10px rgba(0,0,0,0.03); }}
    .score-card h3 {{ color: #64748b; font-size: 14px; margin-bottom: 4px; }}
    .score-card h1 {{ color: #6d28d9; font-size: 32px; }}
    .main-layout {{ display: grid; grid-template-columns: 2fr 1fr; gap: 15px; }}
    .quiz-panel {{ background: white; border-radius: 20px; padding: 25px; box-shadow: 0 4px 15px rgba(0,0,0,0.04); }}
    .progress-top {{ display: flex; justify-content: space-between; margin-bottom: 8px; color: #6d28d9; font-weight: 600; font-size: 14px;}}
    .progress-bar {{ width: 100%; height: 8px; background: #e5e7eb; border-radius: 8px; overflow: hidden; margin-bottom: 20px; }}
    .progress-fill {{ height: 100%; background: linear-gradient(90deg, #7c3aed, #4f46e5); transition: width 0.5s ease-in-out; }}
    .top-tags {{ display: flex; justify-content: space-between; margin-bottom: 20px; }}
    .tag {{ padding: 6px 12px; border-radius: 999px; background: #ede9fe; color: #6d28d9; font-weight: 600; font-size: 12px; }}
    .question {{ font-size: 32px; font-weight: 700; line-height: 1.2; margin-bottom: 12px; }}
    .question-sub {{ font-size: 16px; color: #64748b; margin-bottom: 20px; }}
    .option {{ width: calc(100% - 20px); /* Adjusted width */ padding: 16px; margin-bottom: 12px; border-radius: 15px; border: 1px solid #e5e7eb; background: white; font-size: 16px; cursor: pointer; transition: 0.3s; display: flex; align-items: center; gap: 10px; }}
    .option:hover {{ border-color: #7c3aed; background: #f5f3ff; transform: translateY(-1px); }}
    .option.selected {{ background: #f5f3ff; border-color: #8b5cf6; color: #6d28d9; font-weight: 600; }}
    .option.correct {{ background: #d4edda; border-color: #28a745; color: #155724; }}
    .option.incorrect {{ background: #f8d7da; border-color: #dc3545; color: #721c24; }}
    .radio {{ width: 18px; height: 18px; border-radius: 50%; border: 2px solid #cbd5e1; }}
    .selected .radio {{ border-color: #7c3aed; background: #7c3aed; box-shadow: inset 0 0 0 3px white; }}
    .correct .radio {{ border-color: #28a745; background: #28a745; box-shadow: inset 0 0 0 3px white; }}
    .incorrect .radio {{ border-color: #dc3545; background: #dc3545; box-shadow: inset 0 0 0 3px white; }}
    .buttons {{ display: flex; justify-content: space-between; margin-top: 15px; }}
    .btn {{ padding: 10px 20px; border-radius: 12px; border: none; font-size: 14px; font-weight: 600; cursor: pointer; transition: 0.3s; }}
    .btn-outline {{ background: white; border: 1px solid #ddd; }}
    .btn-primary {{ background: linear-gradient(135deg, #7c3aed, #4f46e5); color: white; box-shadow: 0 5px 10px rgba(124,58,237,0.15); }}
    .btn:hover {{ transform: translateY(-1px); }}
    .sidebar {{ background: white; border-radius: 20px; padding: 20px; box-shadow: 0 4px 15px rgba(0,0,0,0.04); text-align: center; }}
    .trophy {{ font-size: 60px; text-align: center; }}
    .sidebar-title {{ font-size: 28px; font-weight: 700; margin-top: 8px; }}
    .sidebar-sub {{ color: #64748b; margin-top: 8px; font-size: 14px; line-height: 1.4; }}
    .result-card {{ margin-top: 15px; background: #faf5ff; border-radius: 18px; padding: 15px; border: 1px solid #e9d5ff; }}
    .accuracy {{ color: #16a34a; font-size: 18px; font-weight: 600; }}
    .stats {{ display: grid; grid-template-columns: repeat(3,1fr); gap: 8px; margin-top: 15px; }}
    .stat-box {{ background: #f8fafc; border-radius: 12px; padding: 12px; border: 1px solid #eee; }}
    .stat-box h2 {{ font-size: 24px; margin: 6px 0; }}
    .insight {{ margin-top: 15px; background: #faf5ff; border-radius: 15px; padding: 15px; border: 1px solid #e9d5ff; text-align: left; }}
    .insight h3 {{ color: #6d28d9; margin-bottom: 8px; font-size: 16px; }}
    .insight p {{ color: #475569; line-height: 1.5; font-size: 14px; }}
    .sidebar-buttons {{ display: flex; gap: 8px; margin-top: 15px; justify-content: center; }}
    .footer {{ margin-top: 15px; background: white; border-radius: 18px; padding: 15px 20px; display: flex; justify-content: space-between; align-items: center; box-shadow: 0 4px 15px rgba(0,0,0,0.04); }}
    .footer-title {{ color: #6d28d9; font-size: 18px; font-weight: 700; }}
    .footer-sub {{ color: #64748b; margin-top: 4px; font-size: 12px; }}
    @media(max-width:1000px){{ .main-layout{{ grid-template-columns:1fr; }} .question{{ font-size:28px; }} }}

  </style>
</head>
<body>
<div class="container">
  <!-- HEADER -->
  <div class="header">
    <div class="logo-section">
      <div class="logo">🧠</div>
      <div>
        <div class="title">AI Quiz Challenge</div>
        <div class="subtitle">Test your knowledge</div>
      </div>
    </div>
    <div class="score-card">
      <h3>Score</h3>
      <h1 id="header-score">0 / {len(quiz_data)}</h1>
    </div>
  </div>
  <!-- MAIN -->
  <div class="main-layout">
    <!-- LEFT PANEL -->
    <div class="quiz-panel" id="quiz-panel">
      <div class="progress-top">
        <span id="question-number">Question 1 of {len(quiz_data)}</span>
        <span id="progress-percentage">0%</span>
      </div>
      <div class="progress-bar">
        <div class="progress-fill" id="progress-fill"></div>
      </div>
      <div class="top-tags">
        <div class="tag">🌍 Geography</div>
        <div class="tag" id="time-tag">⏱ 00:00</div>
      </div>
      <div class="question" id="question-text">
        What is the largest ocean on Earth?
      </div>
      <div class="question-sub">
        Choose the correct answer from the options below.
      </div>
      <div id="options-container">
        <!-- Options will be dynamically loaded here -->
      </div>
      <div class="buttons">
        <button class="btn btn-outline" id="prev-btn" style="display:none;">← Previous</button>
        <button class="btn btn-primary" id="next-btn">Next →</button>
        <button class="btn btn-primary" id="finish-btn" style="display:none;">⚑ Finish Quiz</button>
      </div>
    </div>
    <!-- RIGHT SIDEBAR -->
    <div class="sidebar" id="sidebar">
      <div id="quiz-in-progress-message">
        <div class="sidebar-title">
          Finish the challenge to unlock results
        </div>
        <div class="sidebar-sub">
          Keep going! Your progress is being tracked.

        </div>
      </div>
      <div id="quiz-completion-content" style="display:none;">
        <div class="trophy">🏆</div>
        <div class="sidebar-title">
          Quiz Completed! 🎉
        </div>
        <div class="sidebar-sub">
          Great effort! Keep learning and challenge yourself more.
        </div>
        <div class="result-card">
          <div>Your Score</div>
          <h1 id="final-score">0 / {len(quiz_data)}</h1>
          <div class="accuracy" id="final-accuracy">Accuracy: 0%</div>
        </div>
        <div class="stats">
          <div class="stat-box">
            <div>✅</div>
            <h2 id="correct-count">0</h2>
            <p>Correct</p>
          </div>
          <div class="stat-box">
            <div>❌</div>
            <h2 id="incorrect-count">0</h2>
            <p>Incorrect</p>
          </div>
          <div class="stat-box">
            <div>📋</div>
            <h2 id="total-count">{len(quiz_data)}</h2>
            <p>Total</p>
          </div>
        </div>
        <div class="insight">
          <h3>🤖 AI Insight</h3>
          <p>
            Keep practicing! You're on the right track.
            Review the explanations and try again to improve your score.
          </p>
        </div>
        <div class="sidebar-buttons">
          <button class="btn btn-outline" id="review-btn">📄 Review Answers</button>
          <button class="btn btn-primary" id="retry-btn">↻ Try Again</button>
        </div>
        <div class="insight" id="time-taken-display">
          <h3>⏱ Time Taken</h3>
          <p id="quiz-time"></p>
        </div>
      </div>
    </div>
  </div>
  <!-- FOOTER -->
  <div class="footer">
    <div>
      <div class="footer-title">🤖 Powered by AI</div>
      <div class="footer-sub">
        Smart quizzes, instant feedback, and AI insights to help you learn better!
      </div>
    </div>
    <button class="btn btn-outline">💡 How it works</button>
  </div>
</div>

<script>
  const quizData = {quiz_data_json};
  let currentQuestionIndex = 0;
  let userAnswers = new Array(quizData.length).fill(null);
  let quizCompleted = false;
  let quizStartTime;
  let timerInterval;

  const questionNumberElem = document.getElementById('question-number');
  const progressPercentageElem = document.getElementById('progress-percentage');
  const progressFillElem = document.getElementById('progress-fill');
  const questionTextElem = document.getElementById('question-text');
  const optionsContainer = document.getElementById('options-container');
  const headerScoreElem = document.getElementById('header-score');
  const prevBtn = document.getElementById('prev-btn');
  const nextBtn = document.getElementById('next-btn');
  const finishBtn = document.getElementById('finish-btn');
  const quizPanel = document.getElementById('quiz-panel');
  const sidebar = document.getElementById('sidebar');
  const finalScoreElem = document.getElementById('final-score');
  const finalAccuracyElem = document.getElementById('final-accuracy');
  const correctCountElem = document.getElementById('correct-count');
  const incorrectCountElem = document.getElementById('incorrect-count');
  const totalCountElem = document.getElementById('total-count');
  const retryBtn = document.getElementById('retry-btn');
  const reviewBtn = document.getElementById('review-btn');
  const timeTagElem = document.getElementById('time-tag');
  const quizTimeElem = document.getElementById('quiz-time');
  const timeTakenDisplayElem = document.getElementById('time-taken-display');
  const quizCompletionContentElem = document.getElementById('quiz-completion-content');
  const quizInProgressMessageElem = document.getElementById('quiz-in-progress-message');

  function startTimer() {{
    quizStartTime = Date.now();
    timerInterval = setInterval(() => {{
      const elapsedTime = Math.floor((Date.now() - quizStartTime) / 1000);
      const minutes = Math.floor(elapsedTime / 60).toString().padStart(2, '0');
      const seconds = (elapsedTime % 60).toString().padStart(2, '0');
      timeTagElem.textContent = `⏱ ${{minutes}}:${{seconds}}`;
    }}, 1000);
  }}

  function stopTimer() {{
    clearInterval(timerInterval);
  }}

  function loadQuestion() {{
    if (currentQuestionIndex < 0 || currentQuestionIndex >= quizData.length) return;

    if (!quizStartTime && !quizCompleted) {{
      startTimer(); // Start timer only once at the beginning of the quiz
    }}

    const question = quizData[currentQuestionIndex];
    questionTextElem.textContent = question.question;
    optionsContainer.innerHTML = ''; // Clear previous options

    question.options.forEach((optionText, index) => {{
      const optionDiv = document.createElement('div');
      optionDiv.classList.add('option');
      optionDiv.innerHTML = `<div class="radio"></div>${{optionText}}`;
      optionDiv.addEventListener('click', () => selectOption(optionDiv, index));
      optionsContainer.appendChild(optionDiv);

      // Restore selection if already answered
      if (userAnswers[currentQuestionIndex] === index) {{
        optionDiv.classList.add('selected');
      }}
       if (quizCompleted) {{
        const correct_answer_index = question.options.indexOf(question.answer);
        if (index === correct_answer_index) {{
          optionDiv.classList.add('correct');
        }} else if (userAnswers[currentQuestionIndex] === index && userAnswers[currentQuestionIndex] !== correct_answer_index) {{
          optionDiv.classList.add('incorrect');
        }}
        optionDiv.style.pointerEvents = 'none'; // Disable clicking after quiz completion
      }}
    }});

    updateProgress();
    updateNavigationButtons();

    // Control visibility of sidebar messages
    if (quizCompleted) {{
      quizInProgressMessageElem.style.display = 'none';
      quizCompletionContentElem.style.display = 'block';
    }} else {{
      quizInProgressMessageElem.style.display = 'block';
      quizCompletionContentElem.style.display = 'none';
    }}
  }}

  function selectOption(selectedOptionDiv, selectedOptionIndex) {{
    if (quizCompleted) return; // Prevent selection after quiz is completed

    // Remove 'selected' class from all options for the current question
    Array.from(optionsContainer.children).forEach(opt => {{
      opt.classList.remove('selected');
    }});

    // Add 'selected' class to the clicked option
    selectedOptionDiv.classList.add('selected');
    userAnswers[currentQuestionIndex] = selectedOptionIndex;
  }}

  function updateProgress() {{
    const progress = ((currentQuestionIndex + 1) / quizData.length) * 100;
    questionNumberElem.textContent = `Question ${{currentQuestionIndex + 1}} of ${{quizData.length}}`;
    progressPercentageElem.textContent = `${{Math.round(progress)}}%`;
    progressFillElem.style.width = `${{progress}}%`;
    updateHeaderScore();
  }}

  function updateHeaderScore() {{
    let correctAnswers = 0;
    for (let i = 0; i < quizData.length; i++) {{
      if (userAnswers[i] !== null && quizData[i].options[userAnswers[i]] === quizData[i].answer) {{
        correctAnswers++;
      }}
    }}
    headerScoreElem.textContent = `${{correctAnswers}} / ${{quizData.length}}`;
  }}

  function updateNavigationButtons() {{
    if (quizCompleted) {{
      // In review mode, show both Prev and Next buttons, but hide Finish
      prevBtn.style.display = currentQuestionIndex > 0 ? 'inline-block' : 'none';
      nextBtn.style.display = currentQuestionIndex < quizData.length - 1 ? 'inline-block' : 'none';
      finishBtn.style.display = 'none';
    }} else {{
      // During quiz, show Prev/Next/Finish based on question position
      prevBtn.style.display = currentQuestionIndex > 0 ? 'inline-block' : 'none';
      nextBtn.style.display = currentQuestionIndex < quizData.length - 1 ? 'inline-block' : 'none';
      finishBtn.style.display = currentQuestionIndex === quizData.length - 1 ? 'inline-block' : 'none';
    }}
  }}

  function calculateResults() {{
    let correct = 0;
    let incorrect = 0;
    for (let i = 0; i < quizData.length; i++) {{
      if (userAnswers[i] !== null && quizData[i].options[userAnswers[i]] === quizData[i].answer) {{
        correct++;
      }}
    }};
    return {{ correct, incorrect, total: quizData.length }};
  }}

  function displayResults() {{
    stopTimer();
    const results = calculateResults();
    quizCompleted = true;
    loadQuestion(); // Re-render current question to show correct/incorrect styling

    // Directly manage button visibility
    nextBtn.style.display = 'none'; // Initially hide next button after finishing
    finishBtn.style.display = 'none';
    prevBtn.style.display = currentQuestionIndex > 0 ? 'inline-block' : 'none'; // Keep previous button for review
    updateNavigationButtons(); // Call to properly set visibility for review mode

    finalScoreElem.textContent = `${{results.correct}} / ${{results.total}}`;
    const accuracy = (results.correct / results.total) * 100;
    finalAccuracyElem.textContent = `Accuracy: ${{Math.round(accuracy)}}%`;
    correctCountElem.textContent = results.correct;
    incorrectCountElem.textContent = results.incorrect;
    totalCountElem.textContent = results.total;

    // Display time taken and quiz completion content
    const elapsedTime = Math.floor((Date.now() - quizStartTime) / 1000);
    const minutes = Math.floor(elapsedTime / 60).toString().padStart(2, '0');
    const seconds = (elapsedTime % 60).toString().padStart(2, '0');
    quizTimeElem.textContent = `${{minutes}} minutes ${{seconds}} seconds`;
    quizInProgressMessageElem.style.display = 'none';
    quizCompletionContentElem.style.display = 'block';
  }}

  prevBtn.addEventListener('click', () => {{
    if (currentQuestionIndex > 0) {{
      currentQuestionIndex--;
      loadQuestion();
    }}
  }});

  nextBtn.addEventListener('click', () => {{
    if (currentQuestionIndex < quizData.length - 1) {{
      currentQuestionIndex++;
      loadQuestion();
    }}
  }});

  finishBtn.addEventListener('click', displayResults);

  retryBtn.addEventListener('click', () => {{
    currentQuestionIndex = 0;
    userAnswers = new Array(quizData.length).fill(null);
    quizCompleted = false;
    quizInProgressMessageElem.style.display = 'block';
    quizCompletionContentElem.style.display = 'none'; // Hide quiz completion content
    timeTagElem.textContent = '⏱ 00:00'; // Reset timer display
    startTimer(); // Restart timer
    loadQuestion();
  }});

  reviewBtn.addEventListener('click', () => {{
    stopTimer(); // Stop timer if reviewing
    currentQuestionIndex = 0;
    loadQuestion(); // Start review from the first question
  }});

  // Initial load
  loadQuestion();
</script>

</body>
</html>
"""

display(HTML(html_content_dynamic))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#   <title>AI Quiz Challenge</title>
#   <style>
#     body { font-family: 'Segoe UI', sans-serif; background: linear-gradient(135deg, #f5f7ff, #eef2ff); padding: 15px; color: #111827; }
#     .container { max-width: 1200px; margin: auto; }
#     .header { background: rgba(255,255,255,0.9); border-radius: 18px; padding: 15px 20px; display: flex; justify-content: space-between; align-items: center; box-shadow: 0 4px 15px rgba(0,0,0,0.04); margin-bottom: 15px; }
#     .logo-section { display: flex; align-items: center; gap: 12px; }
#     .logo { width: 50px; height: 50px; border-radius: 12px; background: linear-gradient(135deg, #7c3aed, #4f46e5); display: flex; align-items: center; justify-content: center; color: white; font-size: 24px; }
#     .title { font-size: 28px; font-weight: 700; }
# ...

# %% [markdown]
# Quiz Completed!
